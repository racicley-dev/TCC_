# %%
import pandas as pd
import os

# %%
#Gerar um arquivo unificado
pasta='arquivos_csv_unidos/'
arquivos = [pd.read_csv(pasta+arquivo) for arquivo in os.listdir(pasta) if os.path.isfile(os.path.join(pasta, arquivo))]
#arquivos

# %%
#Load and Clean
df = pd.concat(arquivos, ignore_index=True)
df = df[['PMID','Title', 'abstract']]
df = df.drop_duplicates()

# %%
df.rename(columns={'Title':'TITLE', 'abstract':'ABSTRACT'}, inplace=True)

# %%
#Removendo os abstracts nulos
df = df[df['ABSTRACT'].isnull() == False]
df
# Out:
#           PMID                                              TITLE  \
# 0     37490085  Identifying Children Likely to Benefit From An...
# 1     14726904  Antimicrobial treatment guidelines for acute b...
# 2     35884010  The Effects of Different Pediatric Drugs and B...
# 3     38117645  The effect of pediatric drugs on color stabili...
# 4     31249178  Effect of different pediatric drug formulation...
# ...        ...                                                ...
# 5606   2847549  Parathyroid hormone stimulates ammoniagenesis ...
# 5607   3386134  Intracellular sodium in proximal tubules of di...
# 5610  11641569  Cariogenic potential of lactosylfructoside as ...
# 5611   3237306  Transport and metabolism of glucose by dissoci...
# 5612   7595773  Hematochezia associated with the use of hypert...
#
#                                                ABSTRACT
# 0     The large overlap between symptoms of acute si...
# 1     Treatment guidelines developed by the Sinus an...
# 2     The aim of the current study is to observe how...
# 3     The long-term use of pediatric medications can...
# 4     Various liquid drug formulations are prescribe...
# ...                                                 ...
# 5606  To determine whether parathyroid hormone (PTH)...
# 5607  Renal hypertrophy is a common consequence of d...
# 5610  The cariogenic potential of lactosylfructoside...
# 5611  A study was carried out to determine the effec...
# 5612  The onset of hematochezia with the use of sodi...
#
# [5030 rows x 3 columns]

# %%
#Abstract iguais
df[df['ABSTRACT'].duplicated() == True].sort_values('ABSTRACT', ascending=True)
# Out:
#           PMID      TITLE      ABSTRACT
# 3319  30000838  Fenugreek  Fenugreek (

# %%
#Abstract iguais
df = df[df['TITLE'].duplicated() == False]
# Out:
#           PMID                                              TITLE  \
# 1116  25381313  "A spoonful of sugar helps the medicine go dow...
# 2058  30568272  "IGT-like" status in normoglucose tolerant obe...
# 5169  37055154  "Make Stories That Will Always Be There": Eagl...
# 5220  37891544  "She gives it to her child who doesn't even ta...
# 5486  36599745  "The curriculum brings equity to the forefront...
# ...        ...                                                ...
# 3181  31447391  α-Ketoglutarate-Activated NF-κB Signaling Prom...
# 2141  36107617  β Cell mass expansion during puberty involves ...
# 2129  37368990  β-Cell Glucose Sensitivity to Assess Changes i...
# 3278  35551509  β-Klotho promotes glycolysis and glucose-stimu...
# 4032  33627831  βA1-crystallin regulates glucose metabolism an...
#
#                                                ABSTRACT
# 1116  Sweeteners are often added to liquid formulati...
# 2058  To assess whether combining glucose shape and ...
# 5169  We aimed to determine why the Eagle Books, an ...
# 5220  There is little research on alcohol and other ...
# 5486  The Accreditation Council for Graduate Medical...
# ...                                                 ...
# 3181  The rapid proliferation of cancer cells and dy...
# 2141  Puberty is associated with transient insulin r...
# 2129  Following a diagnosis of type 1 diabetes (T1D)...
# 3278  Impaired glucose-stimulated insulin secretion ...
# 4032  βA3/A1-crystallin, a lens protein that is also...
#
# [5023 rows x 3 columns]

# %%
#Salve em csv
df.to_csv('csv_buscas.csv')
